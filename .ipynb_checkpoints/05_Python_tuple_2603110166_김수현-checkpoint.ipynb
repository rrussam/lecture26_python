# %% [markdown]
# 튜플 생성과 출력

# %%
t1 = {1, 2, 3}
t2 = {'a', 'b', ('ab', 'cd')}
t3 = ('tuple', (1,2), [3,4])
      
t4 = ()
t5 = (1,)

t6 = 1, 2, 3
t7 = 1,

print(t6)
x, y, z = t6
print(x,y,z)
# Out:
# (1, 2, 3)
# 1 2 3

# %% [markdown]
# 튜플 수정 및 삭제, 활용

# %%
def add_and_mul(a,b) :
    return a+b, a*b

t7 = 1,
del t7

t6 = 3, 2, 7, 4
t8 = sorted(t6)
print(t8)

print(len(t8))
print(max(t8))

x, y = 10, 20
x, y = y, x

result = add_and_mul(3,5)
print(result)
# Out:
# [2, 3, 4, 7]
# 4
# (8, 15)
